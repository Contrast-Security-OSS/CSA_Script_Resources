# %% [markdown]
# # Top Vulnerability Report Notebook
#
# Notebook wrapper for `Reports/top-vulns-report/generate_single_vuln_report.py`.
#
# Outputs are written under `notebooks/top-vulns-report/Output/`.

# %% [markdown]
# ## Flow
# 1. Set env vars manually (Cell 3) or load root `.env` (Cell 4).
# 2. Configure runtime paths (Cell 5).
# 3. Set app selection (Cell 6).
# 4. Run the script (Cell 7).

# %%
import os

os.environ["TEAMSERVER_URL"] = "https://your_saas_instance.contrastsecurity.com/"
os.environ["ORG_UUID"] = ""
os.environ["CONTRAST_AUTH"] = ""
os.environ["CONTRAST_API_KEY"] = ""

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../.env", override=True)
print("Loaded .env from ../../.env")

# %%
from pathlib import Path
from datetime import datetime

def find_repo_root(start):
    current = Path(start).resolve()
    for p in [current, *current.parents]:
        if (p / "notebooks").exists() and (p / "README.md").exists():
            return p
    return current

repo_root = find_repo_root(Path.cwd())
script_path = repo_root / "Reports" / "top-vulns-report" / "generate_single_vuln_report.py"
output_dir = repo_root / "notebooks" / "top-vulns-report" / "Output"
date_str = datetime.now().strftime("%Y-%m-%d")
print("Runtime configuration loaded.")
print(f"Script: {script_path}")
print(f"Output directory: {output_dir}")

# %%
app_name = ""

if not app_name:
    raise ValueError("Set app_name before running the next cell.")

safe_name = app_name.replace(" ", "_").replace("/", "_")
output_path = output_dir / f"top_vuln_{safe_name}_{date_str}.md"
print(f"Output file: {output_path}")

# %%
import subprocess
import sys

cmd = [
    sys.executable, str(script_path),
    "--app-name", app_name,
    "--output", str(output_path)
]

result = subprocess.run(cmd, cwd=repo_root, capture_output=True, text=True)
print(result.stdout)
if result.returncode != 0:
    print(result.stderr)
    raise RuntimeError(f"Script failed with exit code {result.returncode}")
print(f"Done: {output_path}")
